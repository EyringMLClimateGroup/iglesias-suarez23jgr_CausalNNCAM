# %% [markdown]
# # Online evaluation: Cross-sections
#
# This script evaluates hybrid model realizations compared to the original SPCAM model.

# %%
import sys, time, datetime
import sys; sys.path.append("..")
from datetime import datetime as dt
t_init = time.time()

# %%
# To be deleted
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %%
import sys
from utils.online_diagnostics import OnlineDiagnostics

# argv  = sys.argv[1:]
argv  = ["-c", "./nn_config/cfg_online_eval.yml"]

setup = OnlineDiagnostics(argv)

# %% [markdown]
# ## SPCAM Zonal-mean climatologies

# %%
setup.plot_zmClimo(
    'SPCAM',
    'TAP',
    metric='mean',
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2a_zmclimoT_mean_SPCAM.png',
)
# Out:
# ./pnas_plots/fig2a_zmclimoT_mean_SPCAM.png

# %%
setup.plot_zmClimo(
    'SPCAM',
    'QAP',
    metric='mean',
    sin_lats=True,
    cmap='RdBu_r',
    vmin=0., vmax=.015,
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5a_zmclimoq_mean_SPCAM.png',
)
# Out:
# ./pnas_plots/figS5a_zmclimoq_mean_SPCAM.png

# %% [markdown]
# ## Causal & Non-causal NNCAM Zonal-mean climatology biases

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',    
    'TAP',
    ref_simulation='SPCAM',
    metric='mean', vmin=-9., vmax=9.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'fig2b_zmclimoT_mean-bias_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/fig2b_zmclimoT_mean-bias_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',    
    'TAP',
    ref_simulation='SPCAM',
    metric='mean', vmin=-9., vmax=9.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'fig2c_zmclimoT_mean-bias_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/fig2c_zmclimoT_mean-bias_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',    
    'TAP',
    ref_simulation='SPCAM',
    metric='mean', vmin=-9., vmax=9.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimoT_mean-bias_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimoT_mean-bias_Causally-informed0.59NNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',    
    'QAP',
    ref_simulation='SPCAM',
    metric='mean', vmin=-.0015, vmax=.0015,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'figS5b_zmclimoq_mean-bias_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/figS5b_zmclimoq_mean-bias_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',    
    'QAP',
    ref_simulation='SPCAM',
    metric='mean',vmin=-.0015, vmax=.0015,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'figS5c_zmclimoq_mean-bias_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/figS5c_zmclimoq_mean-bias_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',    
    'QAP',
    ref_simulation='SPCAM',
    metric='mean', vmin=-.0015, vmax=.0015,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='both',
    # zm_center=0.,
    size=8,
    aspect=1.2,
    interpolation=5,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimoq_mean-bias_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimoq_mean-bias_Causally-informed0.59NNCAM.png

# %% [markdown]
# ## Zonal-mean climatological variability

# %%
setup.plot_zmClimo(
    'SPCAM',
    'TAP',
    metric='std', vmin=0., vmax=3.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2d_zmclimoT_std_SPCAM.png',
)
# Out:
# ./pnas_plots/fig2d_zmclimoT_std_SPCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',
    'TAP',
    metric='std', vmin=0., vmax=3.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2e_zmclimoT_std_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/fig2e_zmclimoT_std_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',
    'TAP',
    metric='std', vmin=0., vmax=3.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2f_zmclimoT_std_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/fig2f_zmclimoT_std_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',
    'TAP',
    metric='std', vmin=0., vmax=3.,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimoT_std_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimoT_std_Causally-informed0.59NNCAM.png

# %%
setup.plot_zmClimo(
    'SPCAM',
    'QAP',
    metric='std', vmin=0., vmax=.0005,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5d_zmclimoq_std_SPCAM.png',
)
# Out:
# ./pnas_plots/figS5d_zmclimoq_std_SPCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',
    'QAP',
    metric='std', vmin=0., vmax=.0005,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5e_zmclimoq_std_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/figS5e_zmclimoq_std_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',
    'QAP',
    metric='std', vmin=0., vmax=.0005,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5f_zmclimoq_std_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/figS5f_zmclimoq_std_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',
    'QAP',
    metric='std', vmin=0., vmax=.0005,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='max',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimoq_std_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimoq_std_Causally-informed0.59NNCAM.png

# %% [markdown]
# ## Zonal-mean climatological tendencies

# %%
setup.plot_zmClimo(
    'SPCAM',
    'TPHYSTND',
    metric='mean', vmin=-7*1.e-5, vmax=7*1.e-5,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2g_zmclimodtdt_mean_SPCAM.png',
)
# Out:
# ./pnas_plots/fig2g_zmclimodtdt_mean_SPCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',
    'TPHYSTND',
    metric='mean', vmin=-7*1.e-5, vmax=7*1.e-5,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2h_zmclimodtdt_mean_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/fig2h_zmclimodtdt_mean_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',
    'TPHYSTND',
    metric='mean', vmin=-7*1.e-5, vmax=7*1.e-5,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'fig2i_zmclimodtdt_mean_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/fig2i_zmclimodtdt_mean_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',
    'TPHYSTND',
    metric='mean', vmin=-7*1.e-5, vmax=7*1.e-5,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimodtdt_mean_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimodtdt_mean_Causally-informed0.59NNCAM.png

# %%
setup.plot_zmClimo(
    'SPCAM',
    'PHQ',
    metric='mean', vmin=-4*1.e-8, vmax=4*1.e-8,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5g_zmclimodqdt_mean_SPCAM.png',
)
# Out:
# ./pnas_plots/figS5g_zmclimodqdt_mean_SPCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informedNNCAM',
    'PHQ',
    metric='mean', vmin=-4*1.e-8, vmax=4*1.e-8,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5h_zmclimodqdt_mean_Causally-informedNNCAM.png',
)
# Out:
# ./pnas_plots/figS5h_zmclimodqdt_mean_Causally-informedNNCAM.png

# %%
setup.plot_zmClimo(
    'Non-causalNNCAM',
    'PHQ',
    metric='mean', vmin=-4*1.e-8, vmax=4*1.e-8,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS5i_zmclimodqdt_mean_Non-causalNNCAM.png',
)
# Out:
# ./pnas_plots/figS5i_zmclimodqdt_mean_Non-causalNNCAM.png

# %%
setup.plot_zmClimo(
    'Causally-informed0.59NNCAM',
    'PHQ',
    metric='mean', vmin=-4*1.e-8, vmax=4*1.e-8,
    sin_lats=True,
    cmap='RdBu_r',
    alpha=.9,    
    extend='neither',
    size=8,
    aspect=1.2,
    interpolation=5,
    contours=True,
    # save       = './pnas_plots',
    # savenm     = f'figS6_zmclimodqdt_mean_Causally-informed0.59NNCAM.png',
)
# Out:
# ./pnas_plots/figS6_zmclimodqdt_mean_Causally-informed0.59NNCAM.png
